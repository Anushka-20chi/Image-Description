# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka-20chi/Image-Description/blob/main/Image_Description.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from io import IncrementalNewlineDecoder
from sentence_transformers import SentenceTransformer
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
model = SentenceTransformer("clip-ViT-B-32")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.91k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# 0_CLIPModel/model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/604 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
def display_image_and_compare(image_path, text_descriptions):
    ...

# %%
img1 = "/content/Amber_fort.jpg"
img1 = Image.open(img1)

plt.figure(figsize=(6,6))
plt.imshow(img1)
plt.axis("off")
plt.title("Image similarity")
plt.show()

text_description = [
    "Two dogs in the snow",
    "A cat on the table",
    "A picture of london at night",
    "Taj Mahal view",
    "A fort view",
    "A dog sleeping on the couch",
    "Two cats are fighting in the garden"
]

display_image_and_compare("/content/Amber_fort.jpg", text_description)

# %%
def display_image_and_compare(image_path,text_description):
  # loading image
  img = Image.open(image_path)

  #encode image and text(converting both into numbers)
  text_emb = model.encode(text_description)
  img_emb = model.encode(img)

  #compute similarity score
  similarity_score =np.dot(text_emb,img_emb.T)

  # find the best match
  best_match_index =np.argmax(similarity_score)
  best_match_desc = text_description[best_match_index]

  #print the final output
  print(f"\nBest match for image is {best_match_desc} with score of {similarity_score.max()}")
  # display the image
  plt.figure(figsize=(6,6))
  plt.imshow(img)
  plt.axis("off")
  plt.title("Image for similarity comparison",fontsize=14)
  plt.show()

# %%
text_description =["A picture of london at night",
                  "A dog sleeping on the couch",
                   "leaf on the river",
                   "A fort like view",
                   "leaf on the tree",
                   "A sunset view",
                   " A butterfly on sunflower",
                   "fallen leaf"]

# %%
display_image_and_compare("/content/Amber_fort.jpg",text_description)
# Out:
# Best match for image is A fort like view with score of 25.468616485595703

# %%
display_image_and_compare("/content/Leaf.jpg",text_description)
# Out:
# Best match for image is fallen leaf with score of 29.55194854736328

# %%
display_image_and_compare("/content/Sunset view.jpg",text_description)
# Out:
# Best match for image is A sunset view with score of 30.561941146850586

# %%
display_image_and_compare("/content/Butterfly.jpg",text_description)
# Out:
# Best match for image is  A butterfly on sunflower with score of 24.048891067504883
